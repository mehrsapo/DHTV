# %%
from matplotlib import pyplot as plt
import numpy as np
import pickle

# %%
methods =  ['lr', 'dhtv', 'nn2', 'nn6', 'rbf']
n = 30


for data in ['powerplant', 'ale', 'housing', 'autompg']:
    print('--------------------------------------------' + data + '--------------------------------------------')
    for method in methods: 

        if data != 'ale' and method == 'dhtv_irr':
            continue

        print('-----------------------------' + method + '--------------------------')
        folder = 'comp_results/' + data + '_' + method

        test_mses_all = np.loadtxt(folder + '/test_mse70.txt').reshape(n, -1)
        valid_mses_all = np.loadtxt(folder + '/valid_mse70.txt').reshape(n, -1)
        train_mses_all = np.loadtxt(folder + '/train_mse70.txt').reshape(n, -1)
        htv_all = np.loadtxt(folder + '/htv70.txt').reshape(n, -1)
        sparsity_all = np.loadtxt(folder + '/sparsity70.txt').reshape(n, -1)

        htv_dhtv_all = np.loadtxt('comp_results/' + data + '_dhtv'  + '/htv70.txt').reshape(n, -1)
        htv_base = np.mean(htv_dhtv_all[:, 0])
        valid_mses_all = np.nan_to_num(valid_mses_all, nan=np.inf)
        
        if method == 'dhtv' or method == 'dhtv_irr':
            lip_ex_all = np.loadtxt(folder + '/lip_exact70.txt').reshape(n, -1)

        best_lmbdas_idx = np.argmin(valid_mses_all, axis=1)
        
        print('average best train mse:', np.round(np.mean(train_mses_all[range(n), best_lmbdas_idx]),5), np.round(np.std(train_mses_all[range(n), best_lmbdas_idx]),5))
        print('average best valid mse:', np.round(np.mean(valid_mses_all[range(n), best_lmbdas_idx]),5), np.round(np.std(valid_mses_all[range(n), best_lmbdas_idx]),5))
        print('average best test mse:', np.round(np.mean(test_mses_all[range(n), best_lmbdas_idx]),5), np.round(np.std(test_mses_all[range(n), best_lmbdas_idx]),5))
        print('average best htv:', np.round(np.mean(htv_all[range(n), best_lmbdas_idx] / htv_base),2), np.round(np.std(htv_all[range(n), best_lmbdas_idx] / htv_base),2))
        print('average best sparsity:', np.round(np.mean(sparsity_all[range(n), best_lmbdas_idx]),5), np.round(np.std(sparsity_all[range(n), best_lmbdas_idx]),5))
        if method == 'dhtv' or method == 'dhtv_irr':
            print('average best lip exact:', np.round(np.mean(lip_ex_all[range(n), best_lmbdas_idx]),5), np.round(np.std(lip_ex_all[range(n), best_lmbdas_idx]),5))
# Out:
# --------------------------------------------powerplant--------------------------------------------
# -----------------------------lr--------------------------
# average best train mse: 20.8176 0.31846
# average best valid mse: 20.84284 1.21074
# average best test mse: 20.48379 1.12395
# average best htv: 0.0 0.0
# average best sparsity: 1.0 0.0
# -----------------------------dhtv--------------------------
# average best train mse: 1.33772 0.76848
# average best valid mse: 12.82482 1.24324
# average best test mse: 12.33409 1.17081
# average best htv: 0.82 0.06
# average best sparsity: 0.48405 0.03058
# average best lip exact: 452.5615 192.74934
# -----------------------------nn2--------------------------
# average best train mse: 9.49712 0.87569
# average best valid mse: 13.57081 1.24397
# average best test mse: 13.22504 1.12395
# average best htv: 1.85 0.51
# average best sparsity: 0.36226 0.04631
# -----------------------------nn6--------------------------
# average best train mse: 6.88276 1.79756
# average best valid mse: 13.46314 1.41655
# average best test mse: 13.22261 1.23498
# average best htv: 1.57 0.37
# average best sparsity: 0.31726 0.03527
# -----------------------------rbf--------------------------
# average best train mse: 11.43549 0.55373
# average best valid mse: 14.30448 1.25299
# average best test mse: 14.03994 1.13141
# average best htv: 1.9 0.42
# average best sparsity: 0.29832 0.03834
# --------------------------------------------ale--------------------------------------------
# -----------------------------lr--------------------------
# average best train mse: 0.05581 0.00786
# average best valid mse: 0.05444 0.03104
# average best test mse: 0.05809 0.02997
# average best htv: 0.0 0.0
# average best sparsity: 1.0 0.0
# -----------------------------dhtv--------------------------
# average best train mse: 0.02203 0.02237
# average best valid mse: 0.0415 0.02383
# average best test mse: 0.04938 0.02753
# average best htv: 0.75 0.21
# average best sparsity: 0.48472 0.11783
# average best lip exact: 13.71742 10.51209
# -----------------------------nn2--------------------------
# average best train mse: 0.0171 0.01381
# average best valid mse: 0.03483 0.01813
# average best test mse: 0.046 0.02659
# average best htv: 0.92 0.5
# average best sparsity: 0.50498 0.11649
# -----------------------------nn6--------------------------
# average best train mse: 0.01295 0.03584
# average best valid mse: 0.04106 0.01812
# average best test mse: 0.05031 0.02545
# average best htv: 1.22 0.46
# average best sparsity: 0.4227 0.12361
# -----------------------------rbf--------------------------
# average best train mse: 0.01307 0.00664
# average best valid mse: 0.03675 0.01531
# average best test mse: 0.0508 0.02575
# average best htv: 1.39 0.76
# average best sparsity: 0.38819 0.14282
# --------------------------------------------housing--------------------------------------------
# -----------------------------lr--------------------------
# average best train mse: 10128.33315 68.49953
# average best valid mse: 9990.95861 288.0938
# average best test mse: 10074.38866 261.90661
# average best htv: 0.0 0.0
# average best sparsity: 1.0 0.0
# -----------------------------dhtv--------------------------
# average best train mse: 1283.49159 18.88982
# average best valid mse: 2665.73605 140.43055
# average best test mse: 2660.52834 124.37958
# average best htv: 0.81 0.05
# average best sparsity: 0.27136 0.01587
# average best lip exact: 493.81442 29.87868
# -----------------------------nn2--------------------------
# average best train mse: 4458.71291 78.85061
# average best valid mse: 4572.17152 185.86612
# average best test mse: 4615.81309 153.79316
# average best htv: 1.73 0.19
# average best sparsity: 0.09194 0.0162
# -----------------------------nn6--------------------------
# average best train mse: 2644.82822 57.79327
# average best valid mse: 3198.78179 158.53867
# average best test mse: 3230.81308 144.73371
# average best htv: 1.65 0.23
# average best sparsity: 0.10557 0.02326
# -----------------------------rbf--------------------------
# average best train mse: 4680.08196 162.05875
# average best valid mse: 4947.32233 240.19699
# average best test mse: 5149.9709 277.99433
# average best htv: 3.56 1.33
# average best sparsity: 0.17246 0.01985
# --------------------------------------------autompg--------------------------------------------
# -----------------------------lr--------------------------
# average best train mse: 10.86075 0.60678
# average best valid mse: 11.77233 2.32281
# average best test mse: 10.63079 2.18162
# average best htv: 0.0 0.0
# average best sparsity: 1.0 0.0
# -----------------------------dhtv--------------------------
# average best train mse: 1.16849 0.8409
# average best valid mse: 7.52637 1.4943
# average best test mse: 7.47416 1.40057
# average best htv: 0.79 0.15
# average best sparsity: 0.83843 0.02735
# average best lip exact: 4425.99222 2587.14191
# -----------------------------nn2--------------------------
# average best train mse: 3.81332 1.59336
# average best valid mse: 6.92622 1.78309
# average best test mse: 7.49965 2.2587
# average best htv: 0.86 0.25
# average best sparsity: 0.84002 0.05027
# -----------------------------nn6--------------------------
# average best train mse: 4.18211 2.40757
# average best valid mse: 7.29633 1.82087
# average best test mse: 8.37533 2.51242
# average best htv: 1.04 0.45
# average best sparsity: 0.81539 0.08573
# -----------------------------rbf--------------------------
# average best train mse: 2.77234 0.79369
# average best valid mse: 7.27596 1.92222
# average best test mse: 7.95825 2.81052
# average best htv: 0.74 0.18
# average best sparsity: 0.8281 0.03162

# %%
methods = ['dhtv']
data = 'powerplant'
n = 30

for method in methods: 
    print('-----------------------------' + method +  '-' + data + '--------------------------')
    folder = 'comp_results/' + data + '_' + method

    test_mses_all = np.loadtxt(folder + '/test_mse70.txt').reshape(n, -1)
    valid_mses_all = np.loadtxt(folder + '/valid_mse70.txt').reshape(n, -1)
    train_mses_all = np.loadtxt(folder + '/train_mse70.txt').reshape(n, -1)
    htv_all = np.loadtxt(folder + '/htv70.txt').reshape(n, -1)
    sparsity_all = np.loadtxt(folder + '/sparsity70.txt').reshape(n, -1)

    

    if method == 'dhtv':
        lip_exact_all = np.loadtxt(folder + '/lip_exact70.txt').reshape(n, -1)
    elif method != 'rbf':
        lip_all = np.loadtxt(folder + '/lip70.txt').reshape(n, -1)

    valid_mses_all = np.nan_to_num(valid_mses_all, nan=np.inf)

    hyps = [0, 1e-4, 5e-4, 1e-3, 5e-3, 1e-2, 5e-2, 1e-1]

    htv_dhtv_all = np.loadtxt('comp_results/' + data + '_dhtv'  + '/htv70.txt').reshape(n, -1)
    htv_base = np.mean(htv_dhtv_all[:, 0])

    v = np.mean(valid_mses_all, axis=0)
    vs = 1.65* np.std(valid_mses_all, axis=0)/ np.sqrt(n)
    plt.figure(figsize=(7, 4))
    ax1 = plt.subplot()
    l1, =ax1.plot(hyps, v, label='Validation MSE', c='green') 
    ax1.fill_between(hyps, (v-vs), (v+vs), color='green', alpha=.1)
    ax1.set_xscale('log')
    ax1.set_ylabel('Validation MSE', fontsize=12, color='green')

    v = np.mean(sparsity_all, axis=0)
    vs = 1.65 * np.std(sparsity_all, axis=0) / np.sqrt(n)
    ax2 = ax1.twinx()
    l2, = ax2.plot(hyps, v, label='Sparsity', c='orange')   
    ax2.fill_between(hyps, (v-vs), (v+vs), color='orange', alpha=.1)
    ax2.set_xscale('log')
    ax2.set_ylabel('Sparsity', fontsize=12, color='orange')
    
    ax1.set_xlabel('$\lambda$', fontsize = 13)
    plt.legend([l1, l2], ['Validation MSE', 'Sparsity'])
    plt.tight_layout()
    plt.savefig('comp_results/pp-vmsesp.png')
    plt.show()

    v = np.mean(htv_all / htv_base, axis=0)
    vs = 1.65 * np.std(htv_all / htv_base, axis=0) / np.sqrt(n)
    plt.figure(figsize=(7, 4))
    ax1 = plt.subplot()
    l1, = ax1.plot(hyps, v, label='Normalized HTV', c= 'green')   
    ax1.fill_between(hyps, (v-vs), (v+vs), color='green', alpha=.1)
    ax1.set_xscale('log')
    ax1.set_ylabel('HTV Normalized', fontsize=12, color='green')
    
    if method == 'dhtv':
        v = np.mean(lip_exact_all, axis=0)
        vs =  1.65*np.std(lip_exact_all, axis=0) / np.sqrt(n)
        ax2 = ax1.twinx()
        l2, = ax2.plot(hyps, v, label='Exact Lipschitz', c = 'orange')   
        ax2.fill_between(hyps, (v-vs), (v+vs), color='orange', alpha=.1)
        ax2.set_xscale('log')
        #ax2.set_yscale('log')
        ax2.set_ylabel('Exact Lipschitz', fontsize=12, color='orange')
    
    ax1.set_xlabel('$\lambda$', fontsize = 13)
    plt.tight_layout()
    plt.legend([l1, l2], ['Normalized HTV', 'Exact Lipschitz'])
    plt.savefig('comp_results/pp-htvlip.png')
    plt.show()
# Out:
# -----------------------------dhtv-powerplant--------------------------
